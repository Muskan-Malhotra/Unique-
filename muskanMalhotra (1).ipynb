# %%
import pandas as pd
import matplotlib.pyplot as plt

######################################################3
df = pd.read_csv("TCS.NS.csv")
#print(df)

def pnl_func(Open,Close,Volume=500):
    buy = df.Open*df.Volume
    sold = df.Close*df.Volume
    pnl = sold - buy
    return pnl

pnl_func(df.Open,df.Close)       
    
####################################################3
df1 = pd.read_csv("COALINDIA.NS.csv")
#print(df)

def pnl_func1(Open,Close=True,Volume=500):
    buy = df1.Open*df1.Volume
    sold = df1.Close*df1.Volume
    pnl1 = sold - buy
    return pnl1

pnl_func1(df1.Open,df1.Close)

##################################################3
df2 = pd.read_csv("TECHM.NS.csv")
#print(df)

def pnl_func2(Open,Close=True,Volume=500):
    buy = df2.Open*df2.Volume
    sold = df2.Close*df2.Volume
    pnl2 = sold - buy
    return pnl2

pnl_func2(df2.Open,df2.Close)
    
######################################################3
df3 = pd.read_csv("ITC.NS.csv")
#print(df)

def pnl_func3(Open,Close=True,Volume=500):
    buy = df3.Open*df3.Volume
    sold = df3.Close*df3.Volume
    pnl3 = sold - buy
    return pnl3

pnl_func3(df3.Open,df3.Close)
##print("kk",pnl_func3(df.Open,df.Close)+pnl_func2(df2.Open,df2.Close)+pnl_func(df.Open,df.Close)) 



####################################################3
df4 = pd.read_csv("SBIN.NS.csv")
#print(df)

def pnl_func4(Open,Close=True,Volume=500):
    buy = df4.Open*df4.Volume
    sold = df4.Close*df4.Volume
    pnl4= sold - buy
    return pnl4
pnl_func4(df4.Open,df4.Close)  

l=(pnl_func4(df4.Open,df4.Close)+pnl_func3(df3.Open,df3.Close)+pnl_func2(df2.Open,df2.Close)+pnl_func1(df1.Open,df1.Close)+pnl_func(df.Open,df.Close))

x=[df.Date]

plt.hist(x, normed=True, bins=30)


#naming x-axis
plt.xlabel('Date') 
# naming the y axis 
plt.ylabel('Values') 
# giving a title to my graph 
plt.title('Companies last 10yrs Stock')
# Out:
# Text(0.5, 1.0, 'Companies last 10yrs Stock')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np




df = pd.read_csv("TCS.NS.csv")
x=df.Date
# create an index for each tick position
xi = [i for i in range(0, len(x))]
df ['Date'] = np.round(df['Close'].rolling(window=15).mean(),2)
df [['Close','Date']].plot(grid=True,figsize=(28,8))
plt.xticks(xi,x,fontsize=18 )
# naming the x axis 
plt.xlabel('Date',fontsize=20) 
# naming the y axis 
plt.ylabel('Close',fontsize=20) 
# giving a title to my graph 
plt.title('TATA CONSULTANCY SERVICE',fontsize=20)
# show a legend on the plot 
plt.legend(fontsize=20)

  
# function to show the plot 
plt.show() 
#############################################################
df1 = pd.read_csv("COALINDIA.NS.csv")
x=df1.Date
# create an index for each tick position
xi = [i for i in range(0, len(x))]
df1['Date'] = np.round(df['Close'].rolling(window=15).mean(),2)
df1[['Close','Date']].plot(grid=True,figsize=(28,8))
plt.xticks(xi,x,fontsize=18 )

# naming the x axis 
plt.xlabel('Date',fontsize=20) 
# naming the y axis 
plt.ylabel('Close',fontsize=20) 
# giving a title to my graph 
plt.title('COAL INDIA LIMITED',fontsize=20) 
  
# show a legend on the plot 
plt.legend(fontsize=20) 
  
# function to show the plot 
plt.show() 

#####################################################
df2 = pd.read_csv("TECHM.NS.csv")
x=df2.Date
# create an index for each tick position
xi = [i for i in range(0, len(x))]
df2['Date'] = np.round(df['Close'].rolling(window=15).mean(),2)
df2[['Close','Date']].plot(grid=True,figsize=(28,8))
plt.xticks(xi,x,fontsize=18 )
# naming the x axis 
plt.xlabel('Date',fontsize=20) 
# naming the y axis 
plt.ylabel('Close',fontsize=20) 
# giving a title to my graph 
plt.title('TECH MAHINDERA',fontsize=20) 
  
# show a legend on the plot 
plt.legend(fontsize=20) 
  
# function to show the plot 
plt.show() 

############################################################
df3 = pd.read_csv("ITC.NS.csv")
x=df3.Date
# create an index for each tick position
xi = [i for i in range(0, len(x))]
df3['Date'] = np.round(df['Close'].rolling(window=15).mean(),2)
df3[['Close','Date']].plot(grid=True,figsize=(28,8))
plt.xticks(xi,x,fontsize=18 )
# naming the x axis 
plt.xlabel('Date',fontsize=20) 
# naming the y axis 
plt.ylabel('Close',fontsize=20) 
# giving a title to my graph 
plt.title('ITC',fontsize=20) 
  
# show a legend on the plot 
plt.legend(fontsize=20) 
  
# function to show the plot 
plt.show() 

#############################################################
df4 = pd.read_csv("SBIN.NS.csv")
x=df4.Date
# create an index for each tick position
xi = [i for i in range(0, len(x))]
df4['Date'] = np.round(df['Close'].rolling(window=15).mean(),2)
df4[['Close','Date']].plot(grid=True,figsize=(28,8))
plt.xticks(xi,x,fontsize=18 )
# naming the x axis 
plt.xlabel('Date',fontsize=20) 
# naming the y axis 
plt.ylabel('Close',fontsize=20) 
# giving a title to my graph 
plt.title('STATE BANK OF INDIA',fontsize=20) 
  
# show a legend on the plot 
plt.legend(fontsize=20) 
  
# function to show the plot 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("TCS.NS.csv")
x=df.Date
# create an index for each tick position
xi = [i for i in range(0, len(x))]


df[['Open','Close']].plot(figsize = (28,8))
plt.xticks(xi,x,fontsize=18 )

# naming the x axis 
plt.xlabel('Date',fontsize=16) 
# naming the y axis 
plt.ylabel('Open\Close',fontsize=16) 
# giving a title to my graph 
plt.title('TATA CONSULTANCY SERVICES',fontsize=20) 
  
# show a legend on the plot 
plt.legend(fontsize=20) 
  
# function to show the plot 
plt.show() 
#######################################################
df1 = pd.read_csv("COALINDIA.NS.csv")

x=df1.Date
# create an index for each tick position
xi = [i for i in range(0, len(x))]


df1[['Open','Close']].plot(figsize = (28,8))
plt.xticks(xi,x,fontsize=18 )

# naming the x axis 
plt.xlabel('Date',fontsize=20) 
# naming the y axis 
plt.ylabel('Open\Close',fontsize=20) 
# giving a title to my graph 
plt.title('COAL INDIA LIMITED',fontsize=24) 
  
# show a legend on the plot 
plt.legend(fontsize=20) 
  
# function to show the plot 
plt.show() 

##############################################################3
df2 = pd.read_csv("TECHM.NS.csv")

x=df2.Date
# create an index for each tick position
xi = [i for i in range(0, len(x))]


df2[['Open','Close']].plot(figsize = (28,8))
plt.xticks(xi,x,fontsize=18 )

# naming the x axis 
plt.xlabel('Date',fontsize=16) 
# naming the y axis 
plt.ylabel('Open\Close',fontsize=16) 
# giving a title to my graph 
plt.title('TECH MAHINDERA',fontsize=20) 
  
# show a legend on the plot 
plt.legend(fontsize=20) 
  
# function to show the plot 
plt.show() 

##############################################################
df3 = pd.read_csv("ITC.NS.csv")

x=df3.Date
# create an index for each tick position
xi = [i for i in range(0, len(x))]


df3[['Open','Close']].plot(figsize = (28,8))
plt.xticks(xi,x,fontsize=18 )

# naming the x axis 
plt.xlabel('Date',fontsize=20) 
# naming the y axis 
plt.ylabel('Open\Close',fontsize=20) 
# giving a title to my graph 
plt.title('ITC',fontsize=20) 
  
# show a legend on the plot 
plt.legend(fontsize=20) 
  
# function to show the plot 
plt.show() 

#########################################################
df4 = pd.read_csv("SBIN.NS.csv")

x=df4.Date
# create an index for each tick position
xi = [i for i in range(0, len(x))]


df4[['Open','Close']].plot(figsize = (28,8))
plt.xticks(xi,x,fontsize=18 )

# naming the x axis 
plt.xlabel('Date',fontsize=20) 
# naming the y axis 
plt.ylabel('Open\Close',fontsize=20) 
# giving a title to my graph 
plt.title('STATE BANK OF INDIA',fontsize=20) 
  
# show a legend on the plot 
plt.legend(fontsize=20) 
  
# function to show the plot 
plt.show()
